# %%
import requests 
res =requests.get("https://www.guo68.com/sell?page=5",{})
print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=1200"/>
#     <title>水果批发|水果供应信息_中国水果交易网</title>
#     <meta name="keywords" content="水果批发,水果供应"/>
#     <link rel="shortcut icon" href="/favicon.ico" />
# <link rel="stylesheet" type="text/css" href="/css/common.css?66787845364" />
# <link rel="stylesheet" type="text/css" href="/css/font/iconfont.css?66787845364" />    <link rel="stylesheet" type="text/css" href="/css/sell.css?66787845364"/>
#     <style type="text/css">
#
#     </style>
# </head>
# <body>
# <!--头部 header start-->
# <div class="header">
#     <div class="topbar">
#         <div class="content">
#             <ul class="top-phone">
#                 <li>
#                     <a href="https://www.guo68.com/index/down">加入桌面</a>
#                 </li>
#                 <li>
#                     <a href="http://m.guo68.com" target="_blank">手机版</a>
#                 </li>
#                 <li>
# ...
